# %% [markdown]
# - Name: Raisun Lakra
# - Objective: Develop a face recognition system using opencv.
# - Dataset: LFW - People (Face Recognition)
# - Dataset link: https://www.kaggle.com/datasets/atulanandjha/lfwpeople

# %%
import cv2
import dlib
import numpy as np
import os
import shutil
import random
import face_recognition
import pickle

# %%
# video_cap = cv2.VideoCapture(0)
# while True:
#     ret, image = video_cap.read()
#     cv2.imshow("Live Video - Face Recognition", image)
#     if cv2.waitKey == ord("a"):
#         break
# video_cap.release()
# TODO : Resize image

# %% [markdown]
# ### FACE DETECTION

# %%
class FaceDetector():
    def __init__(self, faceCascadePath):
        """ Apply Haar Cascade to detect faces """
        self.faceCascade = cv2.CascadeClassifier(faceCascadePath)
        
        # Check if the cascade is loaded properly
        if self.faceCascade.empty():
            raise ValueError(f"Error loading cascade file: {faceCascadePath}")

    def detect(self, image, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30)):
        """ Return x, y, width, height of detected faces """
        rects = self.faceCascade.detectMultiScale(image, scaleFactor=scaleFactor, minNeighbors=minNeighbors, minSize=minSize)
        return rects

def detect_live():
    # Start video capture from webcam
    video_cap = cv2.VideoCapture(0)
    
    frontal_face_Cascade_Path = "/home/user/Desktop/internship project/Cyfuture-face-recognition-opencv/face-recog-env/lib/python3.13/site-packages/cv2/data/haarcascade_frontalface_default.xml"
    fd = FaceDetector(frontal_face_Cascade_Path)

    while True:
        ret, image = video_cap.read()
        if not ret:
            print("Failed to capture image")
            break

        # Resize the image to a fixed width and height - required for linux to reshape the image as linux is not built for general purpose task. Its default image size too small.
        image_resized = cv2.resize(image, (640, 480))

        # Convert rgb image to grayscale image
        gray_image = cv2.cvtColor(image_resized, cv2.COLOR_BGR2GRAY)

        # Detect faces
        faces = fd.detect(gray_image)

        # Draw rectangles around detected faces
        for x, y, w, h in faces:
            cv2.rectangle(image_resized, (x, y), (x + w, y + h), (127, 255, 0), 2)

        # Show the resized video feed
        cv2.imshow("Live Video - Face Recognition", image_resized)

        # Exit on pressing 'q'
        if cv2.waitKey(1) & 0xFF == ord("q") or cv2.getWindowProperty("Live Video - Face Recognition", cv2.WND_PROP_VISIBLE) < 1:
            break

    # Release resources
    video_cap.release()
    cv2.destroyAllWindows()

# %%
# Uncomment to Run the function
# detect_live()
# Out:
# Failed to capture image
# [ WARN:0@8946.616] global cap_v4l.cpp:913 open VIDEOIO(V4L2:/dev/video0): can't open camera by index
# [ERROR:0@8946.616] global obsensor_uvc_stream_channel.cpp:158 getStreamChannelGroup Camera index out of range

# %% [markdown]
# ### **RESULT**: System is unable to detect face when background is not good like getting sun light from background or in dark room (means low light source). Otherwise for plane bachground it is working good.

# %% [markdown]
# # PREPROCESSING

# %%
# ingest.py

# import random
# import os
# import shutil

def extract_images():
    datasets_path = "../Datasets/images/lfw_funneled/"
    processed_image_path = "../Datasets/processed_images/"
    
    counter = 0
    for person in os.listdir(datasets_path):
        folder_path = os.path.join(datasets_path, person)
        if os.path.isdir(folder_path):
            photos = [photo for photo in os.listdir(folder_path) if photo.lower().endswith(('.jpg','.png', '.jpeg'))]
            if 10 <= len(photos) <= 20:
                selected_photos = photos
            elif len(photos) > 20:
                selected_photos = random.sample(photos, 20)
            else:
                continue
    
            counter += 1
            os.makedirs(processed_image_path, exist_ok=True)
            os.makedirs(os.path.join(processed_image_path, person), exist_ok=True)
    
            for image in selected_photos:
                src = os.path.join(folder_path, image)
                dst = os.path.join(processed_image_path, person, image)
                shutil.copy(src, dst)
        else:
            print(f"{folder_path} is not a directory.")
    print("{} new folders will be created.".format(counter))

# %%
# till now we have extracted required images and implemented face detection

# %%
# Now we have to encode the images and apply face recognition

# %% [markdown]
# ### ENCODE IMAGES

# %%
DATASET_PATH = "../Datasets/processed_images/"
ENCODINGS_FILE = "face_encodings.pkl"

def encode_faces(dataset_path):
    known_encodings = []
    known_names = []

    for person_name in os.listdir(dataset_path):
        person_dir = os.path.join(dataset_path, person_name)

        if not os.path.isdir(person_dir):
            continue

        for image_name in os.listdir(person_dir):
            image_path = os.path.join(person_dir, image_name)
            print(f"Processing {image_path}")

            image = cv2.imread(image_path)
            rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

            # Detect face locations
            face_locations = face_recognition.face_locations(rgb_image)

            # Get face encodings
            encodings = face_recognition.face_encodings(rgb_image, face_locations)

            for encoding in encodings:
                known_encodings.append(encoding)
                known_names.append(person_name)

    # Save encodings
    data = {"encodings": known_encodings, "names": known_names}
    with open(ENCODINGS_FILE, "wb") as f:
        pickle.dump(data, f)

    print("Encoding complete and saved.")

# Run the encoding function
encode_faces(DATASET_PATH)
# Out:
# Processing ../Datasets/processed_images/Richard_Gephardt/Richard_Gephardt_0002.jpg
# Processing ../Datasets/processed_images/Richard_Gephardt/Richard_Gephardt_0011.jpg
# Processing ../Datasets/processed_images/Richard_Gephardt/Richard_Gephardt_0009.jpg
# Processing ../Datasets/processed_images/Richard_Gephardt/Richard_Gephardt_0010.jpg
# Processing ../Datasets/processed_images/Richard_Gephardt/Richard_Gephardt_0003.jpg
# Processing ../Datasets/processed_images/Richard_Gephardt/Richard_Gephardt_0001.jpg
# Processing ../Datasets/processed_images/Richard_Gephardt/Richard_Gephardt_0004.jpg
# Processing ../Datasets/processed_images/Richard_Gephardt/Richard_Gephardt_0005.jpg
# Processing ../Datasets/processed_images/Richard_Gephardt/Richard_Gephardt_0006.jpg
# Processing ../Datasets/processed_images/Richard_Gephardt/Richard_Gephardt_0008.jpg
# Processing ../Datasets/processed_images/Richard_Gephardt/Richard_Gephardt_0007.jpg
# Processing ../Datasets/processed_images/Atal_Bihari_Vajpayee/Atal_Bihari_Vajpayee_0013.jpg
# Processing ../Datasets/processed_images/Atal_Bihari_Vajpayee/Atal_Bihari_Vajpayee_0007.jpg
# Processing ../Datasets/processed_images/Atal_Bihari_Vajpayee/Atal_Bihari_Vajpayee_0024.jpg
# Processing ../Datasets/processed_images/Atal_Bihari_Vajpayee/Atal_Bihari_Vajpayee_0018.jpg
# Processing ../Datasets/processed_images/Atal_Bihari_Vajpayee/Atal_Bihari_Vajpayee_0022.jpg
# Processing ../Datasets/processed_images/Atal_Bihari_Vajpayee/Atal_Bihari_Vajpayee_0003.jpg
# Processing ../Datasets/processed_images/Atal_Bihari_Vajpayee/Atal_Bihari_Vajpayee_0004.jpg
# Processing ../Datasets/processed_images/Atal_Bihari_Vajpayee/Atal_Bihari_Vajpayee_0012.jpg
# Processing ../Datasets/processed_images/Atal_Bihari_Vajpayee/Atal_Bihari_Vajpayee_0005.jpg
# Processing ../Datasets/processed_images/Atal_Bihari_Vajpayee/Atal_Bihari_Vajpayee_0020.jpg
# Processing ../Datasets/processed_images/Atal_Bihari_Vajpayee/Atal_Bihari_Vajpayee_0001.jpg
# Processing ../Datasets/processed_images/Atal_Bihari_Vajpayee/Atal_Bihari_Vajpayee_0015.jpg
# Processing ../Datasets/processed_images/Atal_Bihari_Vajpayee/Atal_Bihari_Vajpayee_0016.jpg
# Processing ../Datasets/processed_images/Atal_Bihari_Vajpayee/Atal_Bihari_Vajpayee_0019.jpg
# Processing ../Datasets/processed_images/Atal_Bihari_Vajpayee/Atal_Bihari_Vajpayee_0014.jpg
# Processing ../Datasets/processed_images/Atal_Bihari_Vajpayee/Atal_Bihari_Vajpayee_0021.jpg
# Processing ../Datasets/processed_images/Atal_Bihari_Vajpayee/Atal_Bihari_Vajpayee_0017.jpg
# Processing ../Datasets/processed_images/Atal_Bihari_Vajpayee/Atal_Bihari_Vajpayee_0002.jpg
# Processing ../Datasets/processed_images/Atal_Bihari_Vajpayee/Atal_Bihari_Vajpayee_0011.jpg
# Processing ../Datasets/processed_images/Atal_Bihari_Vajpayee/Atal_Bihari_Vajpayee_0008.jpg
# Processing ../Datasets/processed_images/Ian_Thorpe/Ian_Thorpe_0009.jpg
# Processing ../Datasets/processed_images/Ian_Thorpe/Ian_Thorpe_0008.jpg
# Processing ../Datasets/processed_images/Ian_Thorpe/Ian_Thorpe_0007.jpg
# Processing ../Datasets/processed_images/Ian_Thorpe/Ian_Thorpe_0010.jpg
# Processing ../Datasets/processed_images/Ian_Thorpe/Ian_Thorpe_0004.jpg
# Processing ../Datasets/processed_images/Ian_Thorpe/Ian_Thorpe_0005.jpg
# Processing ../Datasets/processed_images/Ian_Thorpe/Ian_Thorpe_0006.jpg
# Processing ../Datasets/processed_images/Ian_Thorpe/Ian_Thorpe_0003.jpg
# Processing ../Datasets/processed_images/Ian_Thorpe/Ian_Thorpe_0001.jpg
# Processing ../Datasets/processed_images/Ian_Thorpe/Ian_Thorpe_0002.jpg
# Processing ../Datasets/processed_images/Howard_Dean/Howard_Dean_0004.jpg
# Processing ../Datasets/processed_images/Howard_Dean/Howard_Dean_0012.jpg
# Processing ../Datasets/processed_images/Howard_Dean/Howard_Dean_0008.jpg
# Processing ../Datasets/processed_images/Howard_Dean/Howard_Dean_0006.jpg
# Processing ../Datasets/processed_images/Howard_Dean/Howard_Dean_0009.jpg
# Processing ../Datasets/processed_images/Howard_Dean/Howard_Dean_0011.jpg
# Processing ../Datasets/processed_images/Howard_Dean/Howard_Dean_0007.jpg
# Processing ../Datasets/processed_images/Howard_Dean/Howard_Dean_0002.jpg
# Processing ../Datasets/processed_images/Howard_Dean/Howard_Dean_0001.jpg
# Processing ../Datasets/processed_images/Howard_Dean/Howard_Dean_0010.jpg
# Processing ../Datasets/processed_images/Howard_Dean/Howard_Dean_0003.jpg
# Processing ../Datasets/processed_images/Howard_Dean/Howard_Dean_0005.jpg
# Processing ../Datasets/processed_images/Hans_Blix/Hans_Blix_0024.jpg
# Processing ../Datasets/processed_images/Hans_Blix/Hans_Blix_0034.jpg
# Processing ../Datasets/processed_images/Hans_Blix/Hans_Blix_0007.jpg
# Processing ../Datasets/processed_images/Hans_Blix/Hans_Blix_0006.jpg
# Processing ../Datasets/processed_images/Hans_Blix/Hans_Blix_0009.jpg
# Processing ../Datasets/processed_images/Hans_Blix/Hans_Blix_0031.jpg
# Processing ../Datasets/processed_images/Hans_Blix/Hans_Blix_0032.jpg
# Processing ../Datasets/processed_images/Hans_Blix/Hans_Blix_0033.jpg
# Processing ../Datasets/processed_images/Hans_Blix/Hans_Blix_0023.jpg
# Processing ../Datasets/processed_images/Hans_Blix/Hans_Blix_0026.jpg
# Processing ../Datasets/processed_images/Hans_Blix/Hans_Blix_0016.jpg
# Processing ../Datasets/processed_images/Hans_Blix/Hans_Blix_0025.jpg
# Processing ../Datasets/processed_images/Hans_Blix/Hans_Blix_0002.jpg
# Processing ../Datasets/processed_images/Hans_Blix/Hans_Blix_0030.jpg
# Processing ../Datasets/processed_images/Hans_Blix/Hans_Blix_0038.jpg
# Processing ../Datasets/processed_images/Hans_Blix/Hans_Blix_0015.jpg
# Processing ../Datasets/processed_images/Hans_Blix/Hans_Blix_0011.jpg
# Processing ../Datasets/processed_images/Hans_Blix/Hans_Blix_0014.jpg
# Processing ../Datasets/processed_images/Hans_Blix/Hans_Blix_0019.jpg
# Processing ../Datasets/processed_images/Hans_Blix/Hans_Blix_0013.jpg
# Processing ../Datasets/processed_images/Mahmoud_Abbas/Mahmoud_Abbas_0006.jpg
# Processing ../Datasets/processed_images/Mahmoud_Abbas/Mahmoud_Abbas_0011.jpg
# Processing ../Datasets/processed_images/Mahmoud_Abbas/Mahmoud_Abbas_0020.jpg
# Processing ../Datasets/processed_images/Mahmoud_Abbas/Mahmoud_Abbas_0012.jpg
# Processing ../Datasets/processed_images/Mahmoud_Abbas/Mahmoud_Abbas_0027.jpg
# Processing ../Datasets/processed_images/Mahmoud_Abbas/Mahmoud_Abbas_0008.jpg
# Processing ../Datasets/processed_images/Mahmoud_Abbas/Mahmoud_Abbas_0005.jpg
# Processing ../Datasets/processed_images/Mahmoud_Abbas/Mahmoud_Abbas_0004.jpg
# Processing ../Datasets/processed_images/Mahmoud_Abbas/Mahmoud_Abbas_0013.jpg
# Processing ../Datasets/processed_images/Mahmoud_Abbas/Mahmoud_Abbas_0029.jpg
# Processing ../Datasets/processed_images/Mahmoud_Abbas/Mahmoud_Abbas_0017.jpg
# Processing ../Datasets/processed_images/Mahmoud_Abbas/Mahmoud_Abbas_0018.jpg
# Processing ../Datasets/processed_images/Mahmoud_Abbas/Mahmoud_Abbas_0010.jpg
# Processing ../Datasets/processed_images/Mahmoud_Abbas/Mahmoud_Abbas_0009.jpg
# Processing ../Datasets/processed_images/Mahmoud_Abbas/Mahmoud_Abbas_0015.jpg
# Processing ../Datasets/processed_images/Mahmoud_Abbas/Mahmoud_Abbas_0007.jpg
# Processing ../Datasets/processed_images/Mahmoud_Abbas/Mahmoud_Abbas_0022.jpg
# Processing ../Datasets/processed_images/Mahmoud_Abbas/Mahmoud_Abbas_0024.jpg
# Processing ../Datasets/processed_images/Mahmoud_Abbas/Mahmoud_Abbas_0021.jpg
# Processing ../Datasets/processed_images/Mahmoud_Abbas/Mahmoud_Abbas_0001.jpg
# Processing ../Datasets/processed_images/Abdullah_Gul/Abdullah_Gul_0017.jpg
# Processing ../Datasets/processed_images/Abdullah_Gul/Abdullah_Gul_0010.jpg
# Processing ../Datasets/processed_images/Abdullah_Gul/Abdullah_Gul_0005.jpg
# Processing ../Datasets/processed_images/Abdullah_Gul/Abdullah_Gul_0019.jpg
# Processing ../Datasets/processed_images/Abdullah_Gul/Abdullah_Gul_0011.jpg
# Processing ../Datasets/processed_images/Abdullah_Gul/Abdullah_Gul_0001.jpg
# Processing ../Datasets/processed_images/Abdullah_Gul/Abdullah_Gul_0012.jpg
# Processing ../Datasets/processed_images/Abdullah_Gul/Abdullah_Gul_0002.jpg
# Processing ../Datasets/processed_images/Abdullah_Gul/Abdullah_Gul_0013.jpg
# Processing ../Datasets/processed_images/Abdullah_Gul/Abdullah_Gul_0007.jpg
# Processing ../Datasets/processed_images/Abdullah_Gul/Abdullah_Gul_0018.jpg
# Processing ../Datasets/processed_images/Abdullah_Gul/Abdullah_Gul_0014.jpg
# Processing ../Datasets/processed_images/Abdullah_Gul/Abdullah_Gul_0006.jpg
# Processing ../Datasets/processed_images/Abdullah_Gul/Abdullah_Gul_0003.jpg
# Processing ../Datasets/processed_images/Abdullah_Gul/Abdullah_Gul_0016.jpg
# Processing ../Datasets/processed_images/Abdullah_Gul/Abdullah_Gul_0015.jpg
# Processing ../Datasets/processed_images/Abdullah_Gul/Abdullah_Gul_0008.jpg
# Processing ../Datasets/processed_images/Abdullah_Gul/Abdullah_Gul_0009.jpg
# Processing ../Datasets/processed_images/Abdullah_Gul/Abdullah_Gul_0004.jpg
# Processing ../Datasets/processed_images/John_Ashcroft/John_Ashcroft_0014.jpg
# Processing ../Datasets/processed_images/John_Ashcroft/John_Ashcroft_0017.jpg
# Processing ../Datasets/processed_images/John_Ashcroft/John_Ashcroft_0048.jpg
# Processing ../Datasets/processed_images/John_Ashcroft/John_Ashcroft_0044.jpg
# Processing ../Datasets/processed_images/John_Ashcroft/John_Ashcroft_0030.jpg
# Processing ../Datasets/processed_images/John_Ashcroft/John_Ashcroft_0032.jpg
# Processing ../Datasets/processed_images/John_Ashcroft/John_Ashcroft_0036.jpg
# Processing ../Datasets/processed_images/John_Ashcroft/John_Ashcroft_0004.jpg
# Processing ../Datasets/processed_images/John_Ashcroft/John_Ashcroft_0028.jpg
# Processing ../Datasets/processed_images/John_Ashcroft/John_Ashcroft_0008.jpg
# Processing ../Datasets/processed_images/John_Ashcroft/John_Ashcroft_0012.jpg
# Processing ../Datasets/processed_images/John_Ashcroft/John_Ashcroft_0006.jpg
# Processing ../Datasets/processed_images/John_Ashcroft/John_Ashcroft_0021.jpg
# Processing ../Datasets/processed_images/John_Ashcroft/John_Ashcroft_0007.jpg
# Processing ../Datasets/processed_images/John_Ashcroft/John_Ashcroft_0019.jpg
# Processing ../Datasets/processed_images/John_Ashcroft/John_Ashcroft_0043.jpg
# Processing ../Datasets/processed_images/John_Ashcroft/John_Ashcroft_0039.jpg
# Processing ../Datasets/processed_images/John_Ashcroft/John_Ashcroft_0031.jpg
# Processing ../Datasets/processed_images/John_Ashcroft/John_Ashcroft_0025.jpg
# Processing ../Datasets/processed_images/John_Ashcroft/John_Ashcroft_0038.jpg
# Processing ../Datasets/processed_images/Serena_Williams/Serena_Williams_0048.jpg
# Processing ../Datasets/processed_images/Serena_Williams/Serena_Williams_0019.jpg
# Processing ../Datasets/processed_images/Serena_Williams/Serena_Williams_0025.jpg
# Processing ../Datasets/processed_images/Serena_Williams/Serena_Williams_0001.jpg
# Processing ../Datasets/processed_images/Serena_Williams/Serena_Williams_0011.jpg
# Processing ../Datasets/processed_images/Serena_Williams/Serena_Williams_0045.jpg
# Processing ../Datasets/processed_images/Serena_Williams/Serena_Williams_0004.jpg
# Processing ../Datasets/processed_images/Serena_Williams/Serena_Williams_0038.jpg
# Processing ../Datasets/processed_images/Serena_Williams/Serena_Williams_0002.jpg
# Processing ../Datasets/processed_images/Serena_Williams/Serena_Williams_0016.jpg
# Processing ../Datasets/processed_images/Serena_Williams/Serena_Williams_0022.jpg
# Processing ../Datasets/processed_images/Serena_Williams/Serena_Williams_0041.jpg
# Processing ../Datasets/processed_images/Serena_Williams/Serena_Williams_0043.jpg
# Processing ../Datasets/processed_images/Serena_Williams/Serena_Williams_0050.jpg
# Processing ../Datasets/processed_images/Serena_Williams/Serena_Williams_0042.jpg
# Processing ../Datasets/processed_images/Serena_Williams/Serena_Williams_0021.jpg
# Processing ../Datasets/processed_images/Serena_Williams/Serena_Williams_0028.jpg
# Processing ../Datasets/processed_images/Serena_Williams/Serena_Williams_0020.jpg
# Processing ../Datasets/processed_images/Serena_Williams/Serena_Williams_0005.jpg
# Processing ../Datasets/processed_images/Serena_Williams/Serena_Williams_0018.jpg
# Processing ../Datasets/processed_images/Hillary_Clinton/Hillary_Clinton_0004.jpg
# Processing ../Datasets/processed_images/Hillary_Clinton/Hillary_Clinton_0005.jpg
# Processing ../Datasets/processed_images/Hillary_Clinton/Hillary_Clinton_0009.jpg
# Processing ../Datasets/processed_images/Hillary_Clinton/Hillary_Clinton_0003.jpg
# Processing ../Datasets/processed_images/Hillary_Clinton/Hillary_Clinton_0001.jpg
# Processing ../Datasets/processed_images/Hillary_Clinton/Hillary_Clinton_0013.jpg
# Processing ../Datasets/processed_images/Hillary_Clinton/Hillary_Clinton_0010.jpg
# Processing ../Datasets/processed_images/Hillary_Clinton/Hillary_Clinton_0014.jpg
# Processing ../Datasets/processed_images/Hillary_Clinton/Hillary_Clinton_0006.jpg
# Processing ../Datasets/processed_images/Hillary_Clinton/Hillary_Clinton_0012.jpg
# Processing ../Datasets/processed_images/Hillary_Clinton/Hillary_Clinton_0007.jpg
# Processing ../Datasets/processed_images/Hillary_Clinton/Hillary_Clinton_0002.jpg
# Processing ../Datasets/processed_images/Hillary_Clinton/Hillary_Clinton_0011.jpg
# Processing ../Datasets/processed_images/Hillary_Clinton/Hillary_Clinton_0008.jpg
# Processing ../Datasets/processed_images/Anna_Kournikova/Anna_Kournikova_0005.jpg
# Processing ../Datasets/processed_images/Anna_Kournikova/Anna_Kournikova_0004.jpg
# Processing ../Datasets/processed_images/Anna_Kournikova/Anna_Kournikova_0007.jpg
# Processing ../Datasets/processed_images/Anna_Kournikova/Anna_Kournikova_0009.jpg
# Processing ../Datasets/processed_images/Anna_Kournikova/Anna_Kournikova_0008.jpg
# Processing ../Datasets/processed_images/Anna_Kournikova/Anna_Kournikova_0011.jpg
# Processing ../Datasets/processed_images/Anna_Kournikova/Anna_Kournikova_0003.jpg
# Processing ../Datasets/processed_images/Anna_Kournikova/Anna_Kournikova_0010.jpg
# Processing ../Datasets/processed_images/Anna_Kournikova/Anna_Kournikova_0001.jpg
# Processing ../Datasets/processed_images/Anna_Kournikova/Anna_Kournikova_0012.jpg
# Processing ../Datasets/processed_images/Anna_Kournikova/Anna_Kournikova_0002.jpg
# Processing ../Datasets/processed_images/Anna_Kournikova/Anna_Kournikova_0006.jpg
# Processing ../Datasets/processed_images/Jackie_Chan/Jackie_Chan_0002.jpg
# Processing ../Datasets/processed_images/Jackie_Chan/Jackie_Chan_0005.jpg
# Processing ../Datasets/processed_images/Jackie_Chan/Jackie_Chan_0008.jpg
# Processing ../Datasets/processed_images/Jackie_Chan/Jackie_Chan_0001.jpg
# Processing ../Datasets/processed_images/Jackie_Chan/Jackie_Chan_0013.jpg
# Processing ../Datasets/processed_images/Jackie_Chan/Jackie_Chan_0012.jpg
# Processing ../Datasets/processed_images/Jackie_Chan/Jackie_Chan_0011.jpg
# Processing ../Datasets/processed_images/Jackie_Chan/Jackie_Chan_0006.jpg
# Processing ../Datasets/processed_images/Jackie_Chan/Jackie_Chan_0004.jpg
# Processing ../Datasets/processed_images/Jackie_Chan/Jackie_Chan_0010.jpg
# Processing ../Datasets/processed_images/Jackie_Chan/Jackie_Chan_0009.jpg
# Processing ../Datasets/processed_images/Jackie_Chan/Jackie_Chan_0007.jpg
# Processing ../Datasets/processed_images/Jackie_Chan/Jackie_Chan_0003.jpg
# Processing ../Datasets/processed_images/Tony_Blair/Tony_Blair_0051.jpg
# Processing ../Datasets/processed_images/Tony_Blair/Tony_Blair_0038.jpg
# Processing ../Datasets/processed_images/Tony_Blair/Tony_Blair_0140.jpg
# Processing ../Datasets/processed_images/Tony_Blair/Tony_Blair_0144.jpg
# Processing ../Datasets/processed_images/Tony_Blair/Tony_Blair_0095.jpg
# Processing ../Datasets/processed_images/Tony_Blair/Tony_Blair_0115.jpg
# Processing ../Datasets/processed_images/Tony_Blair/Tony_Blair_0037.jpg
# Processing ../Datasets/processed_images/Tony_Blair/Tony_Blair_0067.jpg
# Processing ../Datasets/processed_images/Tony_Blair/Tony_Blair_0050.jpg
# Processing ../Datasets/processed_images/Tony_Blair/Tony_Blair_0114.jpg
# Processing ../Datasets/processed_images/Tony_Blair/Tony_Blair_0069.jpg
# Processing ../Datasets/processed_images/Tony_Blair/Tony_Blair_0019.jpg
# Processing ../Datasets/processed_images/Tony_Blair/Tony_Blair_0123.jpg
# Processing ../Datasets/processed_images/Tony_Blair/Tony_Blair_0139.jpg
# Processing ../Datasets/processed_images/Tony_Blair/Tony_Blair_0110.jpg
# Processing ../Datasets/processed_images/Tony_Blair/Tony_Blair_0075.jpg
# Processing ../Datasets/processed_images/Tony_Blair/Tony_Blair_0134.jpg
# Processing ../Datasets/processed_images/Tony_Blair/Tony_Blair_0141.jpg
# Processing ../Datasets/processed_images/Tony_Blair/Tony_Blair_0128.jpg
# Processing ../Datasets/processed_images/Tony_Blair/Tony_Blair_0049.jpg
# Processing ../Datasets/processed_images/Lindsay_Davenport/Lindsay_Davenport_0006.jpg
# Processing ../Datasets/processed_images/Lindsay_Davenport/Lindsay_Davenport_0004.jpg
# Processing ../Datasets/processed_images/Lindsay_Davenport/Lindsay_Davenport_0019.jpg
# Processing ../Datasets/processed_images/Lindsay_Davenport/Lindsay_Davenport_0009.jpg
# Processing ../Datasets/processed_images/Lindsay_Davenport/Lindsay_Davenport_0021.jpg
# Processing ../Datasets/processed_images/Lindsay_Davenport/Lindsay_Davenport_0008.jpg
# Processing ../Datasets/processed_images/Lindsay_Davenport/Lindsay_Davenport_0022.jpg
# Processing ../Datasets/processed_images/Lindsay_Davenport/Lindsay_Davenport_0017.jpg
# Processing ../Datasets/processed_images/Lindsay_Davenport/Lindsay_Davenport_0018.jpg
# Processing ../Datasets/processed_images/Lindsay_Davenport/Lindsay_Davenport_0001.jpg
# Processing ../Datasets/processed_images/Lindsay_Davenport/Lindsay_Davenport_0002.jpg
# Processing ../Datasets/processed_images/Lindsay_Davenport/Lindsay_Davenport_0005.jpg
# Processing ../Datasets/processed_images/Lindsay_Davenport/Lindsay_Davenport_0011.jpg
# Processing ../Datasets/processed_images/Lindsay_Davenport/Lindsay_Davenport_0015.jpg
# Processing ../Datasets/processed_images/Lindsay_Davenport/Lindsay_Davenport_0012.jpg
# Processing ../Datasets/processed_images/Lindsay_Davenport/Lindsay_Davenport_0020.jpg
# Processing ../Datasets/processed_images/Lindsay_Davenport/Lindsay_Davenport_0013.jpg
# Processing ../Datasets/processed_images/Lindsay_Davenport/Lindsay_Davenport_0007.jpg
# Processing ../Datasets/processed_images/Lindsay_Davenport/Lindsay_Davenport_0014.jpg
# Processing ../Datasets/processed_images/Lindsay_Davenport/Lindsay_Davenport_0016.jpg
# Processing ../Datasets/processed_images/Recep_Tayyip_Erdogan/Recep_Tayyip_Erdogan_0026.jpg
# Processing ../Datasets/processed_images/Recep_Tayyip_Erdogan/Recep_Tayyip_Erdogan_0011.jpg
# Processing ../Datasets/processed_images/Recep_Tayyip_Erdogan/Recep_Tayyip_Erdogan_0030.jpg
# Processing ../Datasets/processed_images/Recep_Tayyip_Erdogan/Recep_Tayyip_Erdogan_0012.jpg
# Processing ../Datasets/processed_images/Recep_Tayyip_Erdogan/Recep_Tayyip_Erdogan_0021.jpg
# Processing ../Datasets/processed_images/Recep_Tayyip_Erdogan/Recep_Tayyip_Erdogan_0001.jpg
# Processing ../Datasets/processed_images/Recep_Tayyip_Erdogan/Recep_Tayyip_Erdogan_0002.jpg
# Processing ../Datasets/processed_images/Recep_Tayyip_Erdogan/Recep_Tayyip_Erdogan_0029.jpg
# Processing ../Datasets/processed_images/Recep_Tayyip_Erdogan/Recep_Tayyip_Erdogan_0016.jpg
# Processing ../Datasets/processed_images/Recep_Tayyip_Erdogan/Recep_Tayyip_Erdogan_0027.jpg
# Processing ../Datasets/processed_images/Recep_Tayyip_Erdogan/Recep_Tayyip_Erdogan_0004.jpg
# Processing ../Datasets/processed_images/Recep_Tayyip_Erdogan/Recep_Tayyip_Erdogan_0005.jpg
# Processing ../Datasets/processed_images/Recep_Tayyip_Erdogan/Recep_Tayyip_Erdogan_0025.jpg
# Processing ../Datasets/processed_images/Recep_Tayyip_Erdogan/Recep_Tayyip_Erdogan_0023.jpg
# Processing ../Datasets/processed_images/Recep_Tayyip_Erdogan/Recep_Tayyip_Erdogan_0013.jpg
# Processing ../Datasets/processed_images/Recep_Tayyip_Erdogan/Recep_Tayyip_Erdogan_0028.jpg
# Processing ../Datasets/processed_images/Recep_Tayyip_Erdogan/Recep_Tayyip_Erdogan_0019.jpg
# Processing ../Datasets/processed_images/Recep_Tayyip_Erdogan/Recep_Tayyip_Erdogan_0003.jpg
# Processing ../Datasets/processed_images/Recep_Tayyip_Erdogan/Recep_Tayyip_Erdogan_0006.jpg
# Processing ../Datasets/processed_images/Recep_Tayyip_Erdogan/Recep_Tayyip_Erdogan_0008.jpg
# Processing ../Datasets/processed_images/Salma_Hayek/Salma_Hayek_0003.jpg
# Processing ../Datasets/processed_images/Salma_Hayek/Salma_Hayek_0009.jpg
# Processing ../Datasets/processed_images/Salma_Hayek/Salma_Hayek_0005.jpg
# Processing ../Datasets/processed_images/Salma_Hayek/Salma_Hayek_0010.jpg
# Processing ../Datasets/processed_images/Salma_Hayek/Salma_Hayek_0002.jpg
# Processing ../Datasets/processed_images/Salma_Hayek/Salma_Hayek_0011.jpg
# Processing ../Datasets/processed_images/Salma_Hayek/Salma_Hayek_0008.jpg
# Processing ../Datasets/processed_images/Salma_Hayek/Salma_Hayek_0013.jpg
# Processing ../Datasets/processed_images/Salma_Hayek/Salma_Hayek_0001.jpg
# Processing ../Datasets/processed_images/Salma_Hayek/Salma_Hayek_0006.jpg
# Processing ../Datasets/processed_images/Salma_Hayek/Salma_Hayek_0004.jpg
# Processing ../Datasets/processed_images/Salma_Hayek/Salma_Hayek_0012.jpg
# Processing ../Datasets/processed_images/Salma_Hayek/Salma_Hayek_0007.jpg
# Processing ../Datasets/processed_images/John_Bolton/John_Bolton_0003.jpg
# Processing ../Datasets/processed_images/John_Bolton/John_Bolton_0012.jpg
# Processing ../Datasets/processed_images/John_Bolton/John_Bolton_0001.jpg
# Processing ../Datasets/processed_images/John_Bolton/John_Bolton_0011.jpg
# Processing ../Datasets/processed_images/John_Bolton/John_Bolton_0005.jpg
# Processing ../Datasets/processed_images/John_Bolton/John_Bolton_0014.jpg
# Processing ../Datasets/processed_images/John_Bolton/John_Bolton_0015.jpg
# Processing ../Datasets/processed_images/John_Bolton/John_Bolton_0009.jpg
# Processing ../Datasets/processed_images/John_Bolton/John_Bolton_0008.jpg
# Processing ../Datasets/processed_images/John_Bolton/John_Bolton_0007.jpg
# Processing ../Datasets/processed_images/John_Bolton/John_Bolton_0006.jpg
# Processing ../Datasets/processed_images/John_Bolton/John_Bolton_0017.jpg
# Processing ../Datasets/processed_images/John_Bolton/John_Bolton_0016.jpg
# Processing ../Datasets/processed_images/John_Bolton/John_Bolton_0010.jpg
# Processing ../Datasets/processed_images/John_Bolton/John_Bolton_0002.jpg
# Processing ../Datasets/processed_images/John_Bolton/John_Bolton_0004.jpg
# Processing ../Datasets/processed_images/John_Bolton/John_Bolton_0013.jpg
# Processing ../Datasets/processed_images/Alvaro_Uribe/Alvaro_Uribe_0005.jpg
# Processing ../Datasets/processed_images/Alvaro_Uribe/Alvaro_Uribe_0013.jpg
# Processing ../Datasets/processed_images/Alvaro_Uribe/Alvaro_Uribe_0035.jpg
# Processing ../Datasets/processed_images/Alvaro_Uribe/Alvaro_Uribe_0026.jpg
# Processing ../Datasets/processed_images/Alvaro_Uribe/Alvaro_Uribe_0001.jpg
# Processing ../Datasets/processed_images/Alvaro_Uribe/Alvaro_Uribe_0024.jpg
# Processing ../Datasets/processed_images/Alvaro_Uribe/Alvaro_Uribe_0004.jpg
# Processing ../Datasets/processed_images/Alvaro_Uribe/Alvaro_Uribe_0014.jpg
# Processing ../Datasets/processed_images/Alvaro_Uribe/Alvaro_Uribe_0030.jpg
# Processing ../Datasets/processed_images/Alvaro_Uribe/Alvaro_Uribe_0025.jpg
# Processing ../Datasets/processed_images/Alvaro_Uribe/Alvaro_Uribe_0023.jpg
# Processing ../Datasets/processed_images/Alvaro_Uribe/Alvaro_Uribe_0007.jpg
# Processing ../Datasets/processed_images/Alvaro_Uribe/Alvaro_Uribe_0028.jpg
# Processing ../Datasets/processed_images/Alvaro_Uribe/Alvaro_Uribe_0003.jpg
# Processing ../Datasets/processed_images/Alvaro_Uribe/Alvaro_Uribe_0016.jpg
# Processing ../Datasets/processed_images/Alvaro_Uribe/Alvaro_Uribe_0034.jpg
# Processing ../Datasets/processed_images/Alvaro_Uribe/Alvaro_Uribe_0002.jpg
# Processing ../Datasets/processed_images/Alvaro_Uribe/Alvaro_Uribe_0018.jpg
# Processing ../Datasets/processed_images/Alvaro_Uribe/Alvaro_Uribe_0012.jpg
# Processing ../Datasets/processed_images/Alvaro_Uribe/Alvaro_Uribe_0033.jpg
# Processing ../Datasets/processed_images/George_W_Bush/George_W_Bush_0285.jpg
# Processing ../Datasets/processed_images/George_W_Bush/George_W_Bush_0279.jpg
# Processing ../Datasets/processed_images/George_W_Bush/George_W_Bush_0352.jpg
# Processing ../Datasets/processed_images/George_W_Bush/George_W_Bush_0446.jpg
# Processing ../Datasets/processed_images/George_W_Bush/George_W_Bush_0207.jpg
# Processing ../Datasets/processed_images/George_W_Bush/George_W_Bush_0522.jpg
# Processing ../Datasets/processed_images/George_W_Bush/George_W_Bush_0405.jpg
# Processing ../Datasets/processed_images/George_W_Bush/George_W_Bush_0173.jpg
# Processing ../Datasets/processed_images/George_W_Bush/George_W_Bush_0488.jpg
# Processing ../Datasets/processed_images/George_W_Bush/George_W_Bush_0306.jpg
# Processing ../Datasets/processed_images/George_W_Bush/George_W_Bush_0491.jpg
# Processing ../Datasets/processed_images/George_W_Bush/George_W_Bush_0335.jpg
# Processing ../Datasets/processed_images/George_W_Bush/George_W_Bush_0216.jpg
# Processing ../Datasets/processed_images/George_W_Bush/George_W_Bush_0213.jpg
# Processing ../Datasets/processed_images/George_W_Bush/George_W_Bush_0018.jpg
# Processing ../Datasets/processed_images/George_W_Bush/George_W_Bush_0281.jpg
# Processing ../Datasets/processed_images/George_W_Bush/George_W_Bush_0390.jpg
# Processing ../Datasets/processed_images/George_W_Bush/George_W_Bush_0527.jpg
# Processing ../Datasets/processed_images/George_W_Bush/George_W_Bush_0224.jpg
# Processing ../Datasets/processed_images/George_W_Bush/George_W_Bush_0133.jpg
# Processing ../Datasets/processed_images/Donald_Rumsfeld/Donald_Rumsfeld_0089.jpg
# Processing ../Datasets/processed_images/Donald_Rumsfeld/Donald_Rumsfeld_0062.jpg
# Processing ../Datasets/processed_images/Donald_Rumsfeld/Donald_Rumsfeld_0092.jpg
# Processing ../Datasets/processed_images/Donald_Rumsfeld/Donald_Rumsfeld_0031.jpg
# Processing ../Datasets/processed_images/Donald_Rumsfeld/Donald_Rumsfeld_0007.jpg
# Processing ../Datasets/processed_images/Donald_Rumsfeld/Donald_Rumsfeld_0033.jpg
# Processing ../Datasets/processed_images/Donald_Rumsfeld/Donald_Rumsfeld_0008.jpg
# Processing ../Datasets/processed_images/Donald_Rumsfeld/Donald_Rumsfeld_0121.jpg
# Processing ../Datasets/processed_images/Donald_Rumsfeld/Donald_Rumsfeld_0063.jpg
# Processing ../Datasets/processed_images/Donald_Rumsfeld/Donald_Rumsfeld_0104.jpg
# Processing ../Datasets/processed_images/Donald_Rumsfeld/Donald_Rumsfeld_0003.jpg
# Processing ../Datasets/processed_images/Donald_Rumsfeld/Donald_Rumsfeld_0024.jpg
# Processing ../Datasets/processed_images/Donald_Rumsfeld/Donald_Rumsfeld_0053.jpg
# Processing ../Datasets/processed_images/Donald_Rumsfeld/Donald_Rumsfeld_0070.jpg
# Processing ../Datasets/processed_images/Donald_Rumsfeld/Donald_Rumsfeld_0081.jpg
# Processing ../Datasets/processed_images/Donald_Rumsfeld/Donald_Rumsfeld_0047.jpg
# Processing ../Datasets/processed_images/Donald_Rumsfeld/Donald_Rumsfeld_0032.jpg
# Processing ../Datasets/processed_images/Donald_Rumsfeld/Donald_Rumsfeld_0096.jpg
# Processing ../Datasets/processed_images/Donald_Rumsfeld/Donald_Rumsfeld_0067.jpg
# Processing ../Datasets/processed_images/Donald_Rumsfeld/Donald_Rumsfeld_0091.jpg
# Processing ../Datasets/processed_images/Bill_Clinton/Bill_Clinton_0022.jpg
# Processing ../Datasets/processed_images/Bill_Clinton/Bill_Clinton_0003.jpg
# Processing ../Datasets/processed_images/Bill_Clinton/Bill_Clinton_0012.jpg
# Processing ../Datasets/processed_images/Bill_Clinton/Bill_Clinton_0010.jpg
# Processing ../Datasets/processed_images/Bill_Clinton/Bill_Clinton_0016.jpg
# Processing ../Datasets/processed_images/Bill_Clinton/Bill_Clinton_0028.jpg
# Processing ../Datasets/processed_images/Bill_Clinton/Bill_Clinton_0009.jpg
# Processing ../Datasets/processed_images/Bill_Clinton/Bill_Clinton_0018.jpg
# Processing ../Datasets/processed_images/Bill_Clinton/Bill_Clinton_0019.jpg
# Processing ../Datasets/processed_images/Bill_Clinton/Bill_Clinton_0025.jpg
# Processing ../Datasets/processed_images/Bill_Clinton/Bill_Clinton_0008.jpg
# Processing ../Datasets/processed_images/Bill_Clinton/Bill_Clinton_0002.jpg
# Processing ../Datasets/processed_images/Bill_Clinton/Bill_Clinton_0023.jpg
# Processing ../Datasets/processed_images/Bill_Clinton/Bill_Clinton_0024.jpg
# Processing ../Datasets/processed_images/Bill_Clinton/Bill_Clinton_0011.jpg
# Processing ../Datasets/processed_images/Bill_Clinton/Bill_Clinton_0017.jpg
# Processing ../Datasets/processed_images/Bill_Clinton/Bill_Clinton_0001.jpg
# Processing ../Datasets/processed_images/Bill_Clinton/Bill_Clinton_0020.jpg
# Processing ../Datasets/processed_images/Bill_Clinton/Bill_Clinton_0007.jpg
# Processing ../Datasets/processed_images/Bill_Clinton/Bill_Clinton_0026.jpg
# Processing ../Datasets/processed_images/Kim_Clijsters/Kim_Clijsters_0011.jpg
# Processing ../Datasets/processed_images/Kim_Clijsters/Kim_Clijsters_0002.jpg
# Processing ../Datasets/processed_images/Kim_Clijsters/Kim_Clijsters_0010.jpg
# Processing ../Datasets/processed_images/Kim_Clijsters/Kim_Clijsters_0013.jpg
# Processing ../Datasets/processed_images/Kim_Clijsters/Kim_Clijsters_0007.jpg
# Processing ../Datasets/processed_images/Kim_Clijsters/Kim_Clijsters_0004.jpg
# Processing ../Datasets/processed_images/Kim_Clijsters/Kim_Clijsters_0009.jpg
# Processing ../Datasets/processed_images/Kim_Clijsters/Kim_Clijsters_0006.jpg
# Processing ../Datasets/processed_images/Kim_Clijsters/Kim_Clijsters_0003.jpg
# Processing ../Datasets/processed_images/Kim_Clijsters/Kim_Clijsters_0014.jpg
# Processing ../Datasets/processed_images/Kim_Clijsters/Kim_Clijsters_0001.jpg
# Processing ../Datasets/processed_images/Kim_Clijsters/Kim_Clijsters_0008.jpg
# Processing ../Datasets/processed_images/Kim_Clijsters/Kim_Clijsters_0012.jpg
# Processing ../Datasets/processed_images/Kim_Clijsters/Kim_Clijsters_0005.jpg
# Processing ../Datasets/processed_images/Andy_Roddick/Andy_Roddick_0004.jpg
# Processing ../Datasets/processed_images/Andy_Roddick/Andy_Roddick_0010.jpg
# Processing ../Datasets/processed_images/Andy_Roddick/Andy_Roddick_0006.jpg
# Processing ../Datasets/processed_images/Andy_Roddick/Andy_Roddick_0001.jpg
# Processing ../Datasets/processed_images/Andy_Roddick/Andy_Roddick_0005.jpg
# Processing ../Datasets/processed_images/Andy_Roddick/Andy_Roddick_0013.jpg
# Processing ../Datasets/processed_images/Andy_Roddick/Andy_Roddick_0007.jpg
# Processing ../Datasets/processed_images/Andy_Roddick/Andy_Roddick_0011.jpg
# Processing ../Datasets/processed_images/Andy_Roddick/Andy_Roddick_0008.jpg
# Processing ../Datasets/processed_images/Andy_Roddick/Andy_Roddick_0012.jpg
# Processing ../Datasets/processed_images/Andy_Roddick/Andy_Roddick_0014.jpg
# Processing ../Datasets/processed_images/Andy_Roddick/Andy_Roddick_0009.jpg
# Processing ../Datasets/processed_images/Andy_Roddick/Andy_Roddick_0003.jpg
# Processing ../Datasets/processed_images/Andy_Roddick/Andy_Roddick_0015.jpg
# Processing ../Datasets/processed_images/Andy_Roddick/Andy_Roddick_0002.jpg
# Processing ../Datasets/processed_images/Taha_Yassin_Ramadan/Taha_Yassin_Ramadan_0005.jpg
# Processing ../Datasets/processed_images/Taha_Yassin_Ramadan/Taha_Yassin_Ramadan_0010.jpg
# Processing ../Datasets/processed_images/Taha_Yassin_Ramadan/Taha_Yassin_Ramadan_0007.jpg
# Processing ../Datasets/processed_images/Taha_Yassin_Ramadan/Taha_Yassin_Ramadan_0013.jpg
# Processing ../Datasets/processed_images/Taha_Yassin_Ramadan/Taha_Yassin_Ramadan_0008.jpg
# Processing ../Datasets/processed_images/Taha_Yassin_Ramadan/Taha_Yassin_Ramadan_0009.jpg
# Processing ../Datasets/processed_images/Taha_Yassin_Ramadan/Taha_Yassin_Ramadan_0011.jpg
# Processing ../Datasets/processed_images/Taha_Yassin_Ramadan/Taha_Yassin_Ramadan_0015.jpg
# Processing ../Datasets/processed_images/Taha_Yassin_Ramadan/Taha_Yassin_Ramadan_0002.jpg
# Processing ../Datasets/processed_images/Taha_Yassin_Ramadan/Taha_Yassin_Ramadan_0012.jpg
# Processing ../Datasets/processed_images/Taha_Yassin_Ramadan/Taha_Yassin_Ramadan_0006.jpg
# Processing ../Datasets/processed_images/Taha_Yassin_Ramadan/Taha_Yassin_Ramadan_0014.jpg
# Processing ../Datasets/processed_images/Taha_Yassin_Ramadan/Taha_Yassin_Ramadan_0003.jpg
# Processing ../Datasets/processed_images/Taha_Yassin_Ramadan/Taha_Yassin_Ramadan_0001.jpg
# Processing ../Datasets/processed_images/Taha_Yassin_Ramadan/Taha_Yassin_Ramadan_0004.jpg
# Processing ../Datasets/processed_images/Rubens_Barrichello/Rubens_Barrichello_0003.jpg
# Processing ../Datasets/processed_images/Rubens_Barrichello/Rubens_Barrichello_0012.jpg
# Processing ../Datasets/processed_images/Rubens_Barrichello/Rubens_Barrichello_0008.jpg
# Processing ../Datasets/processed_images/Rubens_Barrichello/Rubens_Barrichello_0002.jpg
# Processing ../Datasets/processed_images/Rubens_Barrichello/Rubens_Barrichello_0005.jpg
# Processing ../Datasets/processed_images/Rubens_Barrichello/Rubens_Barrichello_0001.jpg
# Processing ../Datasets/processed_images/Rubens_Barrichello/Rubens_Barrichello_0011.jpg
# Processing ../Datasets/processed_images/Rubens_Barrichello/Rubens_Barrichello_0007.jpg
# Processing ../Datasets/processed_images/Rubens_Barrichello/Rubens_Barrichello_0006.jpg
# Processing ../Datasets/processed_images/Rubens_Barrichello/Rubens_Barrichello_0009.jpg
# Processing ../Datasets/processed_images/Rubens_Barrichello/Rubens_Barrichello_0010.jpg
# Processing ../Datasets/processed_images/Rubens_Barrichello/Rubens_Barrichello_0004.jpg
# Processing ../Datasets/processed_images/Roh_Moo-hyun/Roh_Moo-hyun_0022.jpg
# Processing ../Datasets/processed_images/Roh_Moo-hyun/Roh_Moo-hyun_0006.jpg
# Processing ../Datasets/processed_images/Roh_Moo-hyun/Roh_Moo-hyun_0005.jpg
# Processing ../Datasets/processed_images/Roh_Moo-hyun/Roh_Moo-hyun_0021.jpg
# Processing ../Datasets/processed_images/Roh_Moo-hyun/Roh_Moo-hyun_0027.jpg
# Processing ../Datasets/processed_images/Roh_Moo-hyun/Roh_Moo-hyun_0019.jpg
# Processing ../Datasets/processed_images/Roh_Moo-hyun/Roh_Moo-hyun_0013.jpg
# Processing ../Datasets/processed_images/Roh_Moo-hyun/Roh_Moo-hyun_0012.jpg
# Processing ../Datasets/processed_images/Roh_Moo-hyun/Roh_Moo-hyun_0028.jpg
# Processing ../Datasets/processed_images/Roh_Moo-hyun/Roh_Moo-hyun_0026.jpg
# Processing ../Datasets/processed_images/Roh_Moo-hyun/Roh_Moo-hyun_0018.jpg
# Processing ../Datasets/processed_images/Roh_Moo-hyun/Roh_Moo-hyun_0031.jpg
# Processing ../Datasets/processed_images/Roh_Moo-hyun/Roh_Moo-hyun_0015.jpg
# Processing ../Datasets/processed_images/Roh_Moo-hyun/Roh_Moo-hyun_0011.jpg
# Processing ../Datasets/processed_images/Roh_Moo-hyun/Roh_Moo-hyun_0029.jpg
# Processing ../Datasets/processed_images/Roh_Moo-hyun/Roh_Moo-hyun_0020.jpg
# Processing ../Datasets/processed_images/Roh_Moo-hyun/Roh_Moo-hyun_0025.jpg
# Processing ../Datasets/processed_images/Roh_Moo-hyun/Roh_Moo-hyun_0007.jpg
# Processing ../Datasets/processed_images/Roh_Moo-hyun/Roh_Moo-hyun_0032.jpg
# Processing ../Datasets/processed_images/Roh_Moo-hyun/Roh_Moo-hyun_0023.jpg
# Processing ../Datasets/processed_images/Paul_Bremer/Paul_Bremer_0008.jpg
# Processing ../Datasets/processed_images/Paul_Bremer/Paul_Bremer_0012.jpg
# Processing ../Datasets/processed_images/Paul_Bremer/Paul_Bremer_0006.jpg
# Processing ../Datasets/processed_images/Paul_Bremer/Paul_Bremer_0013.jpg
# Processing ../Datasets/processed_images/Paul_Bremer/Paul_Bremer_0016.jpg
# Processing ../Datasets/processed_images/Paul_Bremer/Paul_Bremer_0003.jpg
# Processing ../Datasets/processed_images/Paul_Bremer/Paul_Bremer_0001.jpg
# Processing ../Datasets/processed_images/Paul_Bremer/Paul_Bremer_0004.jpg
# Processing ../Datasets/processed_images/Paul_Bremer/Paul_Bremer_0017.jpg
# Processing ../Datasets/processed_images/Paul_Bremer/Paul_Bremer_0018.jpg
# Processing ../Datasets/processed_images/Paul_Bremer/Paul_Bremer_0019.jpg
# Processing ../Datasets/processed_images/Paul_Bremer/Paul_Bremer_0002.jpg
# Processing ../Datasets/processed_images/Paul_Bremer/Paul_Bremer_0009.jpg
# Processing ../Datasets/processed_images/Paul_Bremer/Paul_Bremer_0011.jpg
# Processing ../Datasets/processed_images/Paul_Bremer/Paul_Bremer_0007.jpg
# Processing ../Datasets/processed_images/Paul_Bremer/Paul_Bremer_0010.jpg
# Processing ../Datasets/processed_images/Paul_Bremer/Paul_Bremer_0020.jpg
# Processing ../Datasets/processed_images/Paul_Bremer/Paul_Bremer_0005.jpg
# Processing ../Datasets/processed_images/Paul_Bremer/Paul_Bremer_0014.jpg
# Processing ../Datasets/processed_images/Paul_Bremer/Paul_Bremer_0015.jpg
# Processing ../Datasets/processed_images/Mohammad_Khatami/Mohammad_Khatami_0009.jpg
# Processing ../Datasets/processed_images/Mohammad_Khatami/Mohammad_Khatami_0003.jpg
# Processing ../Datasets/processed_images/Mohammad_Khatami/Mohammad_Khatami_0007.jpg
# Processing ../Datasets/processed_images/Mohammad_Khatami/Mohammad_Khatami_0010.jpg
# Processing ../Datasets/processed_images/Mohammad_Khatami/Mohammad_Khatami_0001.jpg
# Processing ../Datasets/processed_images/Mohammad_Khatami/Mohammad_Khatami_0004.jpg
# Processing ../Datasets/processed_images/Mohammad_Khatami/Mohammad_Khatami_0002.jpg
# Processing ../Datasets/processed_images/Mohammad_Khatami/Mohammad_Khatami_0008.jpg
# Processing ../Datasets/processed_images/Mohammad_Khatami/Mohammad_Khatami_0006.jpg
# Processing ../Datasets/processed_images/Mohammad_Khatami/Mohammad_Khatami_0005.jpg
# Processing ../Datasets/processed_images/Nestor_Kirchner/Nestor_Kirchner_0021.jpg
# Processing ../Datasets/processed_images/Nestor_Kirchner/Nestor_Kirchner_0028.jpg
# Processing ../Datasets/processed_images/Nestor_Kirchner/Nestor_Kirchner_0015.jpg
# Processing ../Datasets/processed_images/Nestor_Kirchner/Nestor_Kirchner_0019.jpg
# Processing ../Datasets/processed_images/Nestor_Kirchner/Nestor_Kirchner_0005.jpg
# Processing ../Datasets/processed_images/Nestor_Kirchner/Nestor_Kirchner_0033.jpg
# Processing ../Datasets/processed_images/Nestor_Kirchner/Nestor_Kirchner_0008.jpg
# Processing ../Datasets/processed_images/Nestor_Kirchner/Nestor_Kirchner_0024.jpg
# Processing ../Datasets/processed_images/Nestor_Kirchner/Nestor_Kirchner_0010.jpg
# Processing ../Datasets/processed_images/Nestor_Kirchner/Nestor_Kirchner_0003.jpg
# Processing ../Datasets/processed_images/Nestor_Kirchner/Nestor_Kirchner_0004.jpg
# Processing ../Datasets/processed_images/Nestor_Kirchner/Nestor_Kirchner_0025.jpg
# Processing ../Datasets/processed_images/Nestor_Kirchner/Nestor_Kirchner_0026.jpg
# Processing ../Datasets/processed_images/Nestor_Kirchner/Nestor_Kirchner_0036.jpg
# Processing ../Datasets/processed_images/Nestor_Kirchner/Nestor_Kirchner_0020.jpg
# Processing ../Datasets/processed_images/Nestor_Kirchner/Nestor_Kirchner_0034.jpg
# Processing ../Datasets/processed_images/Nestor_Kirchner/Nestor_Kirchner_0023.jpg
# Processing ../Datasets/processed_images/Nestor_Kirchner/Nestor_Kirchner_0007.jpg
# Processing ../Datasets/processed_images/Nestor_Kirchner/Nestor_Kirchner_0006.jpg
# Processing ../Datasets/processed_images/Nestor_Kirchner/Nestor_Kirchner_0011.jpg
# Processing ../Datasets/processed_images/Dick_Cheney/Dick_Cheney_0010.jpg
# Processing ../Datasets/processed_images/Dick_Cheney/Dick_Cheney_0006.jpg
# Processing ../Datasets/processed_images/Dick_Cheney/Dick_Cheney_0002.jpg
# Processing ../Datasets/processed_images/Dick_Cheney/Dick_Cheney_0014.jpg
# Processing ../Datasets/processed_images/Dick_Cheney/Dick_Cheney_0005.jpg
# Processing ../Datasets/processed_images/Dick_Cheney/Dick_Cheney_0007.jpg
# Processing ../Datasets/processed_images/Dick_Cheney/Dick_Cheney_0009.jpg
# Processing ../Datasets/processed_images/Dick_Cheney/Dick_Cheney_0003.jpg
# Processing ../Datasets/processed_images/Dick_Cheney/Dick_Cheney_0012.jpg
# Processing ../Datasets/processed_images/Dick_Cheney/Dick_Cheney_0013.jpg
# Processing ../Datasets/processed_images/Dick_Cheney/Dick_Cheney_0011.jpg
# Processing ../Datasets/processed_images/Dick_Cheney/Dick_Cheney_0008.jpg
# Processing ../Datasets/processed_images/Dick_Cheney/Dick_Cheney_0004.jpg
# Processing ../Datasets/processed_images/Dick_Cheney/Dick_Cheney_0001.jpg
# Processing ../Datasets/processed_images/Jennifer_Garner/Jennifer_Garner_0011.jpg
# Processing ../Datasets/processed_images/Jennifer_Garner/Jennifer_Garner_0004.jpg
# Processing ../Datasets/processed_images/Jennifer_Garner/Jennifer_Garner_0009.jpg
# Processing ../Datasets/processed_images/Jennifer_Garner/Jennifer_Garner_0001.jpg
# Processing ../Datasets/processed_images/Jennifer_Garner/Jennifer_Garner_0002.jpg
# Processing ../Datasets/processed_images/Jennifer_Garner/Jennifer_Garner_0005.jpg
# Processing ../Datasets/processed_images/Jennifer_Garner/Jennifer_Garner_0003.jpg
# Processing ../Datasets/processed_images/Jennifer_Garner/Jennifer_Garner_0008.jpg
# Processing ../Datasets/processed_images/Jennifer_Garner/Jennifer_Garner_0010.jpg
# Processing ../Datasets/processed_images/Jennifer_Garner/Jennifer_Garner_0012.jpg
# Processing ../Datasets/processed_images/Jennifer_Garner/Jennifer_Garner_0007.jpg
# Processing ../Datasets/processed_images/Jennifer_Garner/Jennifer_Garner_0006.jpg
# Processing ../Datasets/processed_images/Alejandro_Toledo/Alejandro_Toledo_0006.jpg
# Processing ../Datasets/processed_images/Alejandro_Toledo/Alejandro_Toledo_0020.jpg
# Processing ../Datasets/processed_images/Alejandro_Toledo/Alejandro_Toledo_0013.jpg
# Processing ../Datasets/processed_images/Alejandro_Toledo/Alejandro_Toledo_0025.jpg
# Processing ../Datasets/processed_images/Alejandro_Toledo/Alejandro_Toledo_0035.jpg
# Processing ../Datasets/processed_images/Alejandro_Toledo/Alejandro_Toledo_0002.jpg
# Processing ../Datasets/processed_images/Alejandro_Toledo/Alejandro_Toledo_0014.jpg
# Processing ../Datasets/processed_images/Alejandro_Toledo/Alejandro_Toledo_0008.jpg
# Processing ../Datasets/processed_images/Alejandro_Toledo/Alejandro_Toledo_0017.jpg
# Processing ../Datasets/processed_images/Alejandro_Toledo/Alejandro_Toledo_0010.jpg
# Processing ../Datasets/processed_images/Alejandro_Toledo/Alejandro_Toledo_0036.jpg
# Processing ../Datasets/processed_images/Alejandro_Toledo/Alejandro_Toledo_0032.jpg
# Processing ../Datasets/processed_images/Alejandro_Toledo/Alejandro_Toledo_0039.jpg
# Processing ../Datasets/processed_images/Alejandro_Toledo/Alejandro_Toledo_0015.jpg
# Processing ../Datasets/processed_images/Alejandro_Toledo/Alejandro_Toledo_0027.jpg
# Processing ../Datasets/processed_images/Alejandro_Toledo/Alejandro_Toledo_0004.jpg
# Processing ../Datasets/processed_images/Alejandro_Toledo/Alejandro_Toledo_0018.jpg
# Processing ../Datasets/processed_images/Alejandro_Toledo/Alejandro_Toledo_0028.jpg
# Processing ../Datasets/processed_images/Alejandro_Toledo/Alejandro_Toledo_0019.jpg
# Processing ../Datasets/processed_images/Alejandro_Toledo/Alejandro_Toledo_0038.jpg
# Processing ../Datasets/processed_images/Trent_Lott/Trent_Lott_0009.jpg
# Processing ../Datasets/processed_images/Trent_Lott/Trent_Lott_0004.jpg
# Processing ../Datasets/processed_images/Trent_Lott/Trent_Lott_0012.jpg
# Processing ../Datasets/processed_images/Trent_Lott/Trent_Lott_0002.jpg
# Processing ../Datasets/processed_images/Trent_Lott/Trent_Lott_0014.jpg
# Processing ../Datasets/processed_images/Trent_Lott/Trent_Lott_0016.jpg
# Processing ../Datasets/processed_images/Trent_Lott/Trent_Lott_0001.jpg
# Processing ../Datasets/processed_images/Trent_Lott/Trent_Lott_0007.jpg
# Processing ../Datasets/processed_images/Trent_Lott/Trent_Lott_0015.jpg
# Processing ../Datasets/processed_images/Trent_Lott/Trent_Lott_0005.jpg
# Processing ../Datasets/processed_images/Trent_Lott/Trent_Lott_0003.jpg
# Processing ../Datasets/processed_images/Trent_Lott/Trent_Lott_0010.jpg
# Processing ../Datasets/processed_images/Trent_Lott/Trent_Lott_0006.jpg
# Processing ../Datasets/processed_images/Trent_Lott/Trent_Lott_0013.jpg
# Processing ../Datasets/processed_images/Trent_Lott/Trent_Lott_0008.jpg
# Processing ../Datasets/processed_images/Trent_Lott/Trent_Lott_0011.jpg
# Processing ../Datasets/processed_images/Charles_Moose/Charles_Moose_0008.jpg
# Processing ../Datasets/processed_images/Charles_Moose/Charles_Moose_0006.jpg
# Processing ../Datasets/processed_images/Charles_Moose/Charles_Moose_0013.jpg
# Processing ../Datasets/processed_images/Charles_Moose/Charles_Moose_0005.jpg
# Processing ../Datasets/processed_images/Charles_Moose/Charles_Moose_0009.jpg
# Processing ../Datasets/processed_images/Charles_Moose/Charles_Moose_0007.jpg
# Processing ../Datasets/processed_images/Charles_Moose/Charles_Moose_0002.jpg
# Processing ../Datasets/processed_images/Charles_Moose/Charles_Moose_0003.jpg
# Processing ../Datasets/processed_images/Charles_Moose/Charles_Moose_0012.jpg
# Processing ../Datasets/processed_images/Charles_Moose/Charles_Moose_0004.jpg
# Processing ../Datasets/processed_images/Charles_Moose/Charles_Moose_0011.jpg
# Processing ../Datasets/processed_images/Charles_Moose/Charles_Moose_0010.jpg
# Processing ../Datasets/processed_images/Charles_Moose/Charles_Moose_0001.jpg
# Processing ../Datasets/processed_images/Yoriko_Kawaguchi/Yoriko_Kawaguchi_0009.jpg
# Processing ../Datasets/processed_images/Yoriko_Kawaguchi/Yoriko_Kawaguchi_0011.jpg
# Processing ../Datasets/processed_images/Yoriko_Kawaguchi/Yoriko_Kawaguchi_0002.jpg
# Processing ../Datasets/processed_images/Yoriko_Kawaguchi/Yoriko_Kawaguchi_0001.jpg
# Processing ../Datasets/processed_images/Yoriko_Kawaguchi/Yoriko_Kawaguchi_0010.jpg
# Processing ../Datasets/processed_images/Yoriko_Kawaguchi/Yoriko_Kawaguchi_0012.jpg
# Processing ../Datasets/processed_images/Yoriko_Kawaguchi/Yoriko_Kawaguchi_0006.jpg
# Processing ../Datasets/processed_images/Yoriko_Kawaguchi/Yoriko_Kawaguchi_0013.jpg
# Processing ../Datasets/processed_images/Yoriko_Kawaguchi/Yoriko_Kawaguchi_0008.jpg
# Processing ../Datasets/processed_images/Yoriko_Kawaguchi/Yoriko_Kawaguchi_0003.jpg
# Processing ../Datasets/processed_images/Yoriko_Kawaguchi/Yoriko_Kawaguchi_0014.jpg
# Processing ../Datasets/processed_images/Yoriko_Kawaguchi/Yoriko_Kawaguchi_0005.jpg
# Processing ../Datasets/processed_images/Yoriko_Kawaguchi/Yoriko_Kawaguchi_0007.jpg
# Processing ../Datasets/processed_images/Yoriko_Kawaguchi/Yoriko_Kawaguchi_0004.jpg
# Processing ../Datasets/processed_images/Jennifer_Lopez/Jennifer_Lopez_0009.jpg
# Processing ../Datasets/processed_images/Jennifer_Lopez/Jennifer_Lopez_0011.jpg
# Processing ../Datasets/processed_images/Jennifer_Lopez/Jennifer_Lopez_0004.jpg
# Processing ../Datasets/processed_images/Jennifer_Lopez/Jennifer_Lopez_0017.jpg
# Processing ../Datasets/processed_images/Jennifer_Lopez/Jennifer_Lopez_0007.jpg
# Processing ../Datasets/processed_images/Jennifer_Lopez/Jennifer_Lopez_0008.jpg
# Processing ../Datasets/processed_images/Jennifer_Lopez/Jennifer_Lopez_0005.jpg
# Processing ../Datasets/processed_images/Jennifer_Lopez/Jennifer_Lopez_0002.jpg
# Processing ../Datasets/processed_images/Jennifer_Lopez/Jennifer_Lopez_0016.jpg
# Processing ../Datasets/processed_images/Jennifer_Lopez/Jennifer_Lopez_0015.jpg
# Processing ../Datasets/processed_images/Jennifer_Lopez/Jennifer_Lopez_0012.jpg
# Processing ../Datasets/processed_images/Jennifer_Lopez/Jennifer_Lopez_0018.jpg
# Processing ../Datasets/processed_images/Jennifer_Lopez/Jennifer_Lopez_0013.jpg
# Processing ../Datasets/processed_images/Jennifer_Lopez/Jennifer_Lopez_0014.jpg
# Processing ../Datasets/processed_images/Jennifer_Lopez/Jennifer_Lopez_0006.jpg
# Processing ../Datasets/processed_images/Jennifer_Lopez/Jennifer_Lopez_0001.jpg
# Processing ../Datasets/processed_images/Jennifer_Lopez/Jennifer_Lopez_0019.jpg
# Processing ../Datasets/processed_images/Jennifer_Lopez/Jennifer_Lopez_0021.jpg
# Processing ../Datasets/processed_images/Jennifer_Lopez/Jennifer_Lopez_0010.jpg
# Processing ../Datasets/processed_images/Jennifer_Lopez/Jennifer_Lopez_0020.jpg
# Processing ../Datasets/processed_images/Juan_Carlos_Ferrero/Juan_Carlos_Ferrero_0028.jpg
# Processing ../Datasets/processed_images/Juan_Carlos_Ferrero/Juan_Carlos_Ferrero_0002.jpg
# Processing ../Datasets/processed_images/Juan_Carlos_Ferrero/Juan_Carlos_Ferrero_0013.jpg
# Processing ../Datasets/processed_images/Juan_Carlos_Ferrero/Juan_Carlos_Ferrero_0021.jpg
# Processing ../Datasets/processed_images/Juan_Carlos_Ferrero/Juan_Carlos_Ferrero_0017.jpg
# Processing ../Datasets/processed_images/Juan_Carlos_Ferrero/Juan_Carlos_Ferrero_0009.jpg
# Processing ../Datasets/processed_images/Juan_Carlos_Ferrero/Juan_Carlos_Ferrero_0010.jpg
# Processing ../Datasets/processed_images/Juan_Carlos_Ferrero/Juan_Carlos_Ferrero_0024.jpg
# Processing ../Datasets/processed_images/Juan_Carlos_Ferrero/Juan_Carlos_Ferrero_0020.jpg
# Processing ../Datasets/processed_images/Juan_Carlos_Ferrero/Juan_Carlos_Ferrero_0004.jpg
# Processing ../Datasets/processed_images/Juan_Carlos_Ferrero/Juan_Carlos_Ferrero_0025.jpg
# Processing ../Datasets/processed_images/Juan_Carlos_Ferrero/Juan_Carlos_Ferrero_0027.jpg
# Processing ../Datasets/processed_images/Juan_Carlos_Ferrero/Juan_Carlos_Ferrero_0019.jpg
# Processing ../Datasets/processed_images/Juan_Carlos_Ferrero/Juan_Carlos_Ferrero_0006.jpg
# ...
# Processing ../Datasets/processed_images/John_Negroponte/John_Negroponte_0031.jpg
# Processing ../Datasets/processed_images/John_Negroponte/John_Negroponte_0017.jpg
# Processing ../Datasets/processed_images/John_Negroponte/John_Negroponte_0006.jpg
# Processing ../Datasets/processed_images/John_Negroponte/John_Negroponte_0001.jpg
# Processing ../Datasets/processed_images/Bill_Simon/Bill_Simon_0004.jpg
# Processing ../Datasets/processed_images/Bill_Simon/Bill_Simon_0005.jpg
# Processing ../Datasets/processed_images/Bill_Simon/Bill_Simon_0012.jpg
# Processing ../Datasets/processed_images/Bill_Simon/Bill_Simon_0010.jpg
# Processing ../Datasets/processed_images/Bill_Simon/Bill_Simon_0013.jpg
# Processing ../Datasets/processed_images/Bill_Simon/Bill_Simon_0003.jpg
# Processing ../Datasets/processed_images/Bill_Simon/Bill_Simon_0006.jpg
# Processing ../Datasets/processed_images/Bill_Simon/Bill_Simon_0011.jpg
# Processing ../Datasets/processed_images/Bill_Simon/Bill_Simon_0015.jpg
# Processing ../Datasets/processed_images/Bill_Simon/Bill_Simon_0007.jpg
# Processing ../Datasets/processed_images/Bill_Simon/Bill_Simon_0014.jpg
# Processing ../Datasets/processed_images/Bill_Simon/Bill_Simon_0001.jpg
# Processing ../Datasets/processed_images/Bill_Simon/Bill_Simon_0009.jpg
# Processing ../Datasets/processed_images/Bill_Simon/Bill_Simon_0002.jpg
# Processing ../Datasets/processed_images/Bill_Simon/Bill_Simon_0008.jpg
# Processing ../Datasets/processed_images/Joe_Lieberman/Joe_Lieberman_0010.jpg
# Processing ../Datasets/processed_images/Joe_Lieberman/Joe_Lieberman_0013.jpg
# Processing ../Datasets/processed_images/Joe_Lieberman/Joe_Lieberman_0011.jpg
# Processing ../Datasets/processed_images/Joe_Lieberman/Joe_Lieberman_0004.jpg
# Processing ../Datasets/processed_images/Joe_Lieberman/Joe_Lieberman_0012.jpg
# Processing ../Datasets/processed_images/Joe_Lieberman/Joe_Lieberman_0008.jpg
# Processing ../Datasets/processed_images/Joe_Lieberman/Joe_Lieberman_0007.jpg
# Processing ../Datasets/processed_images/Joe_Lieberman/Joe_Lieberman_0001.jpg
# Processing ../Datasets/processed_images/Joe_Lieberman/Joe_Lieberman_0009.jpg
# Processing ../Datasets/processed_images/Joe_Lieberman/Joe_Lieberman_0003.jpg
# Processing ../Datasets/processed_images/Joe_Lieberman/Joe_Lieberman_0002.jpg
# Processing ../Datasets/processed_images/Joe_Lieberman/Joe_Lieberman_0005.jpg
# Processing ../Datasets/processed_images/Joe_Lieberman/Joe_Lieberman_0006.jpg
# Processing ../Datasets/processed_images/Harrison_Ford/Harrison_Ford_0005.jpg
# Processing ../Datasets/processed_images/Harrison_Ford/Harrison_Ford_0003.jpg
# Processing ../Datasets/processed_images/Harrison_Ford/Harrison_Ford_0012.jpg
# Processing ../Datasets/processed_images/Harrison_Ford/Harrison_Ford_0001.jpg
# Processing ../Datasets/processed_images/Harrison_Ford/Harrison_Ford_0007.jpg
# Processing ../Datasets/processed_images/Harrison_Ford/Harrison_Ford_0002.jpg
# Processing ../Datasets/processed_images/Harrison_Ford/Harrison_Ford_0010.jpg
# Processing ../Datasets/processed_images/Harrison_Ford/Harrison_Ford_0008.jpg
# Processing ../Datasets/processed_images/Harrison_Ford/Harrison_Ford_0006.jpg
# Processing ../Datasets/processed_images/Harrison_Ford/Harrison_Ford_0004.jpg
# Processing ../Datasets/processed_images/Harrison_Ford/Harrison_Ford_0011.jpg
# Processing ../Datasets/processed_images/Harrison_Ford/Harrison_Ford_0009.jpg
# Processing ../Datasets/processed_images/Hamid_Karzai/Hamid_Karzai_0014.jpg
# Processing ../Datasets/processed_images/Hamid_Karzai/Hamid_Karzai_0012.jpg
# Processing ../Datasets/processed_images/Hamid_Karzai/Hamid_Karzai_0004.jpg
# Processing ../Datasets/processed_images/Hamid_Karzai/Hamid_Karzai_0010.jpg
# Processing ../Datasets/processed_images/Hamid_Karzai/Hamid_Karzai_0018.jpg
# Processing ../Datasets/processed_images/Hamid_Karzai/Hamid_Karzai_0013.jpg
# Processing ../Datasets/processed_images/Hamid_Karzai/Hamid_Karzai_0019.jpg
# Processing ../Datasets/processed_images/Hamid_Karzai/Hamid_Karzai_0007.jpg
# Processing ../Datasets/processed_images/Hamid_Karzai/Hamid_Karzai_0011.jpg
# Processing ../Datasets/processed_images/Hamid_Karzai/Hamid_Karzai_0022.jpg
# Processing ../Datasets/processed_images/Hamid_Karzai/Hamid_Karzai_0017.jpg
# Processing ../Datasets/processed_images/Hamid_Karzai/Hamid_Karzai_0006.jpg
# Processing ../Datasets/processed_images/Hamid_Karzai/Hamid_Karzai_0005.jpg
# Processing ../Datasets/processed_images/Hamid_Karzai/Hamid_Karzai_0020.jpg
# Processing ../Datasets/processed_images/Hamid_Karzai/Hamid_Karzai_0008.jpg
# Processing ../Datasets/processed_images/Hamid_Karzai/Hamid_Karzai_0003.jpg
# Processing ../Datasets/processed_images/Hamid_Karzai/Hamid_Karzai_0015.jpg
# Processing ../Datasets/processed_images/Hamid_Karzai/Hamid_Karzai_0021.jpg
# Processing ../Datasets/processed_images/Hamid_Karzai/Hamid_Karzai_0016.jpg
# Processing ../Datasets/processed_images/Hamid_Karzai/Hamid_Karzai_0001.jpg
# Processing ../Datasets/processed_images/John_Howard/John_Howard_0012.jpg
# Processing ../Datasets/processed_images/John_Howard/John_Howard_0002.jpg
# Processing ../Datasets/processed_images/John_Howard/John_Howard_0013.jpg
# Processing ../Datasets/processed_images/John_Howard/John_Howard_0016.jpg
# Processing ../Datasets/processed_images/John_Howard/John_Howard_0004.jpg
# Processing ../Datasets/processed_images/John_Howard/John_Howard_0019.jpg
# Processing ../Datasets/processed_images/John_Howard/John_Howard_0003.jpg
# Processing ../Datasets/processed_images/John_Howard/John_Howard_0010.jpg
# Processing ../Datasets/processed_images/John_Howard/John_Howard_0005.jpg
# Processing ../Datasets/processed_images/John_Howard/John_Howard_0015.jpg
# Processing ../Datasets/processed_images/John_Howard/John_Howard_0007.jpg
# Processing ../Datasets/processed_images/John_Howard/John_Howard_0018.jpg
# Processing ../Datasets/processed_images/John_Howard/John_Howard_0006.jpg
# Processing ../Datasets/processed_images/John_Howard/John_Howard_0017.jpg
# Processing ../Datasets/processed_images/John_Howard/John_Howard_0011.jpg
# Processing ../Datasets/processed_images/John_Howard/John_Howard_0014.jpg
# Processing ../Datasets/processed_images/John_Howard/John_Howard_0009.jpg
# Processing ../Datasets/processed_images/John_Howard/John_Howard_0008.jpg
# Processing ../Datasets/processed_images/John_Howard/John_Howard_0001.jpg
# Processing ../Datasets/processed_images/Jennifer_Capriati/Jennifer_Capriati_0036.jpg
# Processing ../Datasets/processed_images/Jennifer_Capriati/Jennifer_Capriati_0028.jpg
# Processing ../Datasets/processed_images/Jennifer_Capriati/Jennifer_Capriati_0025.jpg
# Processing ../Datasets/processed_images/Jennifer_Capriati/Jennifer_Capriati_0006.jpg
# Processing ../Datasets/processed_images/Jennifer_Capriati/Jennifer_Capriati_0031.jpg
# Processing ../Datasets/processed_images/Jennifer_Capriati/Jennifer_Capriati_0014.jpg
# Processing ../Datasets/processed_images/Jennifer_Capriati/Jennifer_Capriati_0021.jpg
# Processing ../Datasets/processed_images/Jennifer_Capriati/Jennifer_Capriati_0035.jpg
# Processing ../Datasets/processed_images/Jennifer_Capriati/Jennifer_Capriati_0030.jpg
# Processing ../Datasets/processed_images/Jennifer_Capriati/Jennifer_Capriati_0009.jpg
# Processing ../Datasets/processed_images/Jennifer_Capriati/Jennifer_Capriati_0029.jpg
# Processing ../Datasets/processed_images/Jennifer_Capriati/Jennifer_Capriati_0003.jpg
# Processing ../Datasets/processed_images/Jennifer_Capriati/Jennifer_Capriati_0015.jpg
# Processing ../Datasets/processed_images/Jennifer_Capriati/Jennifer_Capriati_0022.jpg
# Processing ../Datasets/processed_images/Jennifer_Capriati/Jennifer_Capriati_0039.jpg
# Processing ../Datasets/processed_images/Jennifer_Capriati/Jennifer_Capriati_0020.jpg
# Processing ../Datasets/processed_images/Jennifer_Capriati/Jennifer_Capriati_0041.jpg
# Processing ../Datasets/processed_images/Jennifer_Capriati/Jennifer_Capriati_0024.jpg
# Processing ../Datasets/processed_images/Jennifer_Capriati/Jennifer_Capriati_0038.jpg
# Processing ../Datasets/processed_images/Jennifer_Capriati/Jennifer_Capriati_0004.jpg
# Processing ../Datasets/processed_images/Tom_Ridge/Tom_Ridge_0003.jpg
# Processing ../Datasets/processed_images/Tom_Ridge/Tom_Ridge_0030.jpg
# Processing ../Datasets/processed_images/Tom_Ridge/Tom_Ridge_0016.jpg
# Processing ../Datasets/processed_images/Tom_Ridge/Tom_Ridge_0001.jpg
# Processing ../Datasets/processed_images/Tom_Ridge/Tom_Ridge_0024.jpg
# Processing ../Datasets/processed_images/Tom_Ridge/Tom_Ridge_0033.jpg
# Processing ../Datasets/processed_images/Tom_Ridge/Tom_Ridge_0028.jpg
# Processing ../Datasets/processed_images/Tom_Ridge/Tom_Ridge_0002.jpg
# Processing ../Datasets/processed_images/Tom_Ridge/Tom_Ridge_0004.jpg
# Processing ../Datasets/processed_images/Tom_Ridge/Tom_Ridge_0032.jpg
# Processing ../Datasets/processed_images/Tom_Ridge/Tom_Ridge_0020.jpg
# Processing ../Datasets/processed_images/Tom_Ridge/Tom_Ridge_0010.jpg
# Processing ../Datasets/processed_images/Tom_Ridge/Tom_Ridge_0015.jpg
# Processing ../Datasets/processed_images/Tom_Ridge/Tom_Ridge_0027.jpg
# Processing ../Datasets/processed_images/Tom_Ridge/Tom_Ridge_0025.jpg
# Processing ../Datasets/processed_images/Tom_Ridge/Tom_Ridge_0014.jpg
# Processing ../Datasets/processed_images/Tom_Ridge/Tom_Ridge_0008.jpg
# Processing ../Datasets/processed_images/Tom_Ridge/Tom_Ridge_0007.jpg
# Processing ../Datasets/processed_images/Tom_Ridge/Tom_Ridge_0018.jpg
# Processing ../Datasets/processed_images/Tom_Ridge/Tom_Ridge_0013.jpg
# Processing ../Datasets/processed_images/Jacques_Chirac/Jacques_Chirac_0024.jpg
# Processing ../Datasets/processed_images/Jacques_Chirac/Jacques_Chirac_0005.jpg
# Processing ../Datasets/processed_images/Jacques_Chirac/Jacques_Chirac_0051.jpg
# Processing ../Datasets/processed_images/Jacques_Chirac/Jacques_Chirac_0043.jpg
# Processing ../Datasets/processed_images/Jacques_Chirac/Jacques_Chirac_0027.jpg
# Processing ../Datasets/processed_images/Jacques_Chirac/Jacques_Chirac_0039.jpg
# Processing ../Datasets/processed_images/Jacques_Chirac/Jacques_Chirac_0018.jpg
# Processing ../Datasets/processed_images/Jacques_Chirac/Jacques_Chirac_0029.jpg
# Processing ../Datasets/processed_images/Jacques_Chirac/Jacques_Chirac_0034.jpg
# Processing ../Datasets/processed_images/Jacques_Chirac/Jacques_Chirac_0017.jpg
# Processing ../Datasets/processed_images/Jacques_Chirac/Jacques_Chirac_0013.jpg
# Processing ../Datasets/processed_images/Jacques_Chirac/Jacques_Chirac_0049.jpg
# Processing ../Datasets/processed_images/Jacques_Chirac/Jacques_Chirac_0006.jpg
# Processing ../Datasets/processed_images/Jacques_Chirac/Jacques_Chirac_0037.jpg
# Processing ../Datasets/processed_images/Jacques_Chirac/Jacques_Chirac_0031.jpg
# Processing ../Datasets/processed_images/Jacques_Chirac/Jacques_Chirac_0036.jpg
# Processing ../Datasets/processed_images/Jacques_Chirac/Jacques_Chirac_0044.jpg
# Processing ../Datasets/processed_images/Jacques_Chirac/Jacques_Chirac_0020.jpg
# Processing ../Datasets/processed_images/Jacques_Chirac/Jacques_Chirac_0004.jpg
# Processing ../Datasets/processed_images/Jacques_Chirac/Jacques_Chirac_0019.jpg
# Processing ../Datasets/processed_images/Igor_Ivanov/Igor_Ivanov_0018.jpg
# Processing ../Datasets/processed_images/Igor_Ivanov/Igor_Ivanov_0003.jpg
# Processing ../Datasets/processed_images/Igor_Ivanov/Igor_Ivanov_0011.jpg
# Processing ../Datasets/processed_images/Igor_Ivanov/Igor_Ivanov_0002.jpg
# Processing ../Datasets/processed_images/Igor_Ivanov/Igor_Ivanov_0017.jpg
# Processing ../Datasets/processed_images/Igor_Ivanov/Igor_Ivanov_0020.jpg
# Processing ../Datasets/processed_images/Igor_Ivanov/Igor_Ivanov_0006.jpg
# Processing ../Datasets/processed_images/Igor_Ivanov/Igor_Ivanov_0001.jpg
# Processing ../Datasets/processed_images/Igor_Ivanov/Igor_Ivanov_0007.jpg
# Processing ../Datasets/processed_images/Igor_Ivanov/Igor_Ivanov_0014.jpg
# Processing ../Datasets/processed_images/Igor_Ivanov/Igor_Ivanov_0015.jpg
# Processing ../Datasets/processed_images/Igor_Ivanov/Igor_Ivanov_0010.jpg
# Processing ../Datasets/processed_images/Igor_Ivanov/Igor_Ivanov_0005.jpg
# Processing ../Datasets/processed_images/Igor_Ivanov/Igor_Ivanov_0004.jpg
# Processing ../Datasets/processed_images/Igor_Ivanov/Igor_Ivanov_0008.jpg
# Processing ../Datasets/processed_images/Igor_Ivanov/Igor_Ivanov_0013.jpg
# Processing ../Datasets/processed_images/Igor_Ivanov/Igor_Ivanov_0019.jpg
# Processing ../Datasets/processed_images/Igor_Ivanov/Igor_Ivanov_0009.jpg
# Processing ../Datasets/processed_images/Igor_Ivanov/Igor_Ivanov_0012.jpg
# Processing ../Datasets/processed_images/Igor_Ivanov/Igor_Ivanov_0016.jpg
# Processing ../Datasets/processed_images/Edmund_Stoiber/Edmund_Stoiber_0003.jpg
# Processing ../Datasets/processed_images/Edmund_Stoiber/Edmund_Stoiber_0011.jpg
# Processing ../Datasets/processed_images/Edmund_Stoiber/Edmund_Stoiber_0013.jpg
# Processing ../Datasets/processed_images/Edmund_Stoiber/Edmund_Stoiber_0005.jpg
# Processing ../Datasets/processed_images/Edmund_Stoiber/Edmund_Stoiber_0002.jpg
# Processing ../Datasets/processed_images/Edmund_Stoiber/Edmund_Stoiber_0010.jpg
# Processing ../Datasets/processed_images/Edmund_Stoiber/Edmund_Stoiber_0012.jpg
# Processing ../Datasets/processed_images/Edmund_Stoiber/Edmund_Stoiber_0004.jpg
# Processing ../Datasets/processed_images/Edmund_Stoiber/Edmund_Stoiber_0007.jpg
# Processing ../Datasets/processed_images/Edmund_Stoiber/Edmund_Stoiber_0001.jpg
# Processing ../Datasets/processed_images/Edmund_Stoiber/Edmund_Stoiber_0009.jpg
# Processing ../Datasets/processed_images/Edmund_Stoiber/Edmund_Stoiber_0008.jpg
# Processing ../Datasets/processed_images/Edmund_Stoiber/Edmund_Stoiber_0006.jpg
# Processing ../Datasets/processed_images/Richard_Myers/Richard_Myers_0008.jpg
# Processing ../Datasets/processed_images/Richard_Myers/Richard_Myers_0010.jpg
# Processing ../Datasets/processed_images/Richard_Myers/Richard_Myers_0015.jpg
# Processing ../Datasets/processed_images/Richard_Myers/Richard_Myers_0006.jpg
# Processing ../Datasets/processed_images/Richard_Myers/Richard_Myers_0013.jpg
# Processing ../Datasets/processed_images/Richard_Myers/Richard_Myers_0007.jpg
# Processing ../Datasets/processed_images/Richard_Myers/Richard_Myers_0016.jpg
# Processing ../Datasets/processed_images/Richard_Myers/Richard_Myers_0018.jpg
# Processing ../Datasets/processed_images/Richard_Myers/Richard_Myers_0001.jpg
# Processing ../Datasets/processed_images/Richard_Myers/Richard_Myers_0014.jpg
# Processing ../Datasets/processed_images/Richard_Myers/Richard_Myers_0009.jpg
# Processing ../Datasets/processed_images/Richard_Myers/Richard_Myers_0012.jpg
# Processing ../Datasets/processed_images/Richard_Myers/Richard_Myers_0004.jpg
# Processing ../Datasets/processed_images/Richard_Myers/Richard_Myers_0003.jpg
# Processing ../Datasets/processed_images/Richard_Myers/Richard_Myers_0011.jpg
# Processing ../Datasets/processed_images/Richard_Myers/Richard_Myers_0002.jpg
# Processing ../Datasets/processed_images/Richard_Myers/Richard_Myers_0017.jpg
# Processing ../Datasets/processed_images/Richard_Myers/Richard_Myers_0005.jpg
# Processing ../Datasets/processed_images/Halle_Berry/Halle_Berry_0010.jpg
# Processing ../Datasets/processed_images/Halle_Berry/Halle_Berry_0002.jpg
# Processing ../Datasets/processed_images/Halle_Berry/Halle_Berry_0005.jpg
# Processing ../Datasets/processed_images/Halle_Berry/Halle_Berry_0006.jpg
# Processing ../Datasets/processed_images/Halle_Berry/Halle_Berry_0016.jpg
# Processing ../Datasets/processed_images/Halle_Berry/Halle_Berry_0015.jpg
# Processing ../Datasets/processed_images/Halle_Berry/Halle_Berry_0003.jpg
# Processing ../Datasets/processed_images/Halle_Berry/Halle_Berry_0014.jpg
# Processing ../Datasets/processed_images/Halle_Berry/Halle_Berry_0013.jpg
# Processing ../Datasets/processed_images/Halle_Berry/Halle_Berry_0004.jpg
# Processing ../Datasets/processed_images/Halle_Berry/Halle_Berry_0007.jpg
# Processing ../Datasets/processed_images/Halle_Berry/Halle_Berry_0001.jpg
# Processing ../Datasets/processed_images/Halle_Berry/Halle_Berry_0011.jpg
# Processing ../Datasets/processed_images/Halle_Berry/Halle_Berry_0008.jpg
# Processing ../Datasets/processed_images/Halle_Berry/Halle_Berry_0009.jpg
# Processing ../Datasets/processed_images/Halle_Berry/Halle_Berry_0012.jpg
# Encoding complete and saved.

# %% [markdown]
# ###  LIVE FACE RECOGNITION

# %%
# ENCODINGS_FILE = "face_encodings.pkl"

# # Load encodings
# with open(ENCODINGS_FILE, "rb") as f:
#     data = pickle.load(f)

# video_capture = cv2.VideoCapture(0)

# while True:
#     ret, frame = video_capture.read()
#     if not ret:
#         print("Failed to capture image")
#         break

#     rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

#     # Detect faces
#     face_locations = face_recognition.face_locations(rgb_frame)
#     face_encodings = face_recognition.face_encodings(rgb_frame, face_locations)

#     for (top, right, bottom, left), face_encoding in zip(face_locations, face_encodings):
#         matches = face_recognition.compare_faces(data["encodings"], face_encoding, tolerance=0.4)
#         name = "Unknown"

#         # Find the best match
#         face_distances = face_recognition.face_distance(data["encodings"], face_encoding)
#         best_match_index = np.argmin(face_distances)

#         if matches[best_match_index]:
#             name = data["names"][best_match_index]

#         # Draw rectangle and label
#         cv2.rectangle(frame, (left, top), (right, bottom), (0, 255, 0), 2)
#         cv2.putText(frame, name, (left, top - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)

#     # Show output
#     cv2.imshow("Face Recognition", frame)

#     # Exit on 'q'
#     if cv2.waitKey(1) & 0xFF == ord("q"):
#         break

# video_capture.release()
# cv2.destroyAllWindows()

# %%
ENCODINGS_FILE = "face_encodings.pkl"

# Load encodings
with open(ENCODINGS_FILE, "rb") as f:
    data = pickle.load(f)

video_capture = cv2.VideoCapture(0)

while True:
    ret, frame = video_capture.read()
    if not ret:
        print("Failed to capture image")
        break

    rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

    # detect face and encode them
    face_locations = face_recognition.face_locations(rgb_frame)
    face_encodings = face_recognition.face_encodings(rgb_frame, face_locations)

    for (top, right, bottom, left), face_encoding in zip(face_locations, face_encodings):
        face_distances = face_recognition.face_distance(data["encodings"], face_encoding)
        best_match_index = np.argmin(face_distances)

        # set threshold = 0.4 to strict threshold for unknown faces
        threshold = 0.4
        if face_distances[best_match_index] < threshold:
            name = data["names"][best_match_index]
            confidence = 1 - face_distances[best_match_index]
        else:
            name = "Unknown"
            confidence = 0

        # Draw ractangle and label them with confidence
        label = f"{name} ({confidence:.2f})"
        cv2.rectangle(frame, (left, top), (right, bottom), (0, 255, 0), 2)
        cv2.putText(frame, label, (left, top - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)

    cv2.imshow("Face Recognition", frame)

    # Press 'q' to exit
    if cv2.waitKey(1) & 0xFF == ord("q"):
        break

video_capture.release()
cv2.destroyAllWindows()
# Out:
# Failed to capture image
# [ WARN:0@8760.909] global cap_v4l.cpp:913 open VIDEOIO(V4L2:/dev/video0): can't open camera by index
# [ERROR:0@8760.909] global obsensor_uvc_stream_channel.cpp:158 getStreamChannelGroup Camera index out of range

# %% [markdown]
# ### Try knn for more accuracy

# %%
from sklearn.neighbors import KNeighborsClassifier

# Load encoded face data
with open("face_encodings.pkl", "rb") as f:
    data = pickle.load(f)

# Train k-NN with stored face encodings
knn = KNeighborsClassifier(n_neighbors=3, metric="euclidean")
knn.fit(data["encodings"], data["names"])

# Save the trained model
with open("knn_face_model.pkl", "wb") as f:
    pickle.dump(knn, f)

print("k-NN model trained and saved!")

# %%
import cv2
import face_recognition
import pickle

# Load trained k-NN model
with open("knn_face_model.pkl", "rb") as f:
    knn = pickle.load(f)

video_capture = cv2.VideoCapture(0)

while True:
    ret, frame = video_capture.read()
    if not ret:
        break

    rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

    face_locations = face_recognition.face_locations(rgb_frame)
    face_encodings = face_recognition.face_encodings(rgb_frame, face_locations)

    for (top, right, bottom, left), face_encoding in zip(face_locations, face_encodings):
        # Predict name using k-NN
        name = knn.predict([face_encoding])[0]

        cv2.rectangle(frame, (left, top), (right, bottom), (0, 255, 0), 2)
        cv2.putText(frame, name, (left, top - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)

    cv2.imshow("Face Recognition with k-NN", frame)

    if cv2.waitKey(1) & 0xFF == ord("q"):
        break

video_capture.release()
cv2.destroyAllWindows()

# %%
# import cv2
# import face_recognition
# import numpy as np
# from src.utils import load_encodings
# import pickle

def load_encodings(encodings_file):
    with open(encodings_file, "rb") as f:
        data = pickle.load(f)
    return data

class FaceDetector:
    def __init__(self, faceCascadePath):
        """Apply Haar Cascade to detect faces."""
        self.faceCascade = cv2.CascadeClassifier(faceCascadePath)
        
        # Check if the cascade is loaded properly
        if self.faceCascade.empty():
            raise ValueError(f"Error loading cascade file: {faceCascadePath}")

    def detect(self, image, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30)):
        """Return x, y, width, height of detected faces."""
        rects = self.faceCascade.detectMultiScale(image, scaleFactor=scaleFactor, minNeighbors=minNeighbors, minSize=minSize)
        return rects

def detect_live(encodings_file="face_encodings.pkl"):
    data = load_encodings(encodings_file)

    # Start video capture from webcam
    video_cap = cv2.VideoCapture(0)
    
    # frontal_face_Cascade_Path = "src/haarcascade_frontalface_default.xml"
    frontal_face_Cascade_Path = "/home/user/Desktop/internship project/Cyfuture-face-recognition-opencv/face-recog-env/lib/python3.13/site-packages/cv2/data/haarcascade_frontalface_default.xml"
    fd = FaceDetector(frontal_face_Cascade_Path)

    while True:
        ret, frame = video_cap.read()
        if not ret:
            print("Failed to capture image")
            break

        # Resize the image to a fixed width and height - required for linux to reshape the image as linux is not built for general purpose task. Its default image size too small.
        frame_resized = cv2.resize(frame, (640, 480))

        # Convert rgb image to grayscale image for face detection
        gray_image = cv2.cvtColor(frame_resized, cv2.COLOR_BGR2GRAY)

        # Detect faces using Haar Cascade
        faces = fd.detect(gray_image)

        # Convert the frame to RGB for face recognition
        rgb_frame = cv2.cvtColor(frame_resized, cv2.COLOR_BGR2RGB)

        # Recognize faces
        for (x, y, w, h) in faces:
            face_image = rgb_frame[y:y+h, x:x+w]

            # Get face encodings for the detected face
            face_encodings = face_recognition.face_encodings(face_image)

            if len(face_encodings) > 0:
                face_encoding = face_encodings[0]

                # Compare face encoding with known encodings
                face_distances = face_recognition.face_distance(data["encodings"], face_encoding)
                best_match_index = np.argmin(face_distances)

                # Set a strict threshold (0.4) for recognition
                threshold = 0.4
                if face_distances[best_match_index] < threshold:
                    name = data["names"][best_match_index]
                    confidence = 1 - face_distances[best_match_index]
                else:
                    name = "Unknown"
                    confidence = 0

                # Draw rectangle and label with confidence
                label = f"{name} ({confidence:.2f})"
                cv2.rectangle(frame_resized, (x, y), (x + w, y + h), (127, 255, 0), 2)
                cv2.putText(frame_resized, label, (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (127, 255, 0), 2)

        # Show the resized video feed
        cv2.imshow("Live Video - Face Recognition", frame_resized)

        # Exit on pressing 'q'
        if cv2.waitKey(1) & 0xFF == ord("q") or cv2.getWindowProperty("Live Video - Face Recognition", cv2.WND_PROP_VISIBLE) < 1:
            break

    # Release resources
    video_cap.release()
    cv2.destroyAllWindows()

# %%
detect_live()
# Out:
# Failed to capture image
# [ WARN:0@9079.090] global cap_v4l.cpp:913 open VIDEOIO(V4L2:/dev/video0): can't open camera by index
# [ERROR:0@9079.090] global obsensor_uvc_stream_channel.cpp:158 getStreamChannelGroup Camera index out of range
